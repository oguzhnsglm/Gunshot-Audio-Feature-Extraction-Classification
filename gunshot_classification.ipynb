# %% [markdown]
# <a href="https://www.kaggle.com/code/ouzhansalam/gunshot-audio-feature-extraction-classification?scriptVersionId=249426841" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import os
import librosa
import numpy as np
import pandas as pd

def extract_features(file_path):
    """
    Ses dosyasından birçok özellik çıkarır.
    """
    try:
        audio, sample_rate = librosa.load(file_path, sr=None)
        zero_crossing = np.mean(librosa.feature.zero_crossing_rate(y=audio).T, axis=0)
        spectral_centroid = np.mean(librosa.feature.spectral_centroid(y=audio, sr=sample_rate).T, axis=0)
        spectral_rolloff = np.mean(librosa.feature.spectral_rolloff(y=audio, sr=sample_rate).T, axis=0)
        spectral_bandwidth = np.mean(librosa.feature.spectral_bandwidth(y=audio, sr=sample_rate).T, axis=0)
        
        spectral_contrast = librosa.feature.spectral_contrast(y=audio, sr=sample_rate)
        contrast_mean = np.mean(spectral_contrast, axis=1)
        contrast_std = np.std(spectral_contrast, axis=1)
        
        chroma_stft = librosa.feature.chroma_stft(y=audio, sr=sample_rate)
        chroma_stft_mean = np.mean(chroma_stft, axis=1)
        chroma_stft_std = np.std(chroma_stft, axis=1)
        
        rms_mean = np.mean(librosa.feature.rms(y=audio))
        
        mel_spectrogram = librosa.feature.melspectrogram(y=audio, sr=sample_rate)
        melspectrogram_mean = np.mean(mel_spectrogram)
        melspectrogram_std = np.std(mel_spectrogram)
        
        flatness_mean = np.mean(librosa.feature.spectral_flatness(y=audio))
        
        poly_features = librosa.feature.poly_features(y=audio, sr=sample_rate, order=1)
        poly_mean = np.mean(poly_features, axis=1)
        
        mfcc = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfcc_mean = np.mean(mfcc, axis=1)
        mfcc_std = np.std(mfcc, axis=1)
        
        energy = np.sum(audio ** 2)
        
        features = np.hstack([
            zero_crossing, spectral_centroid, spectral_rolloff, spectral_bandwidth,
            contrast_mean, contrast_std, chroma_stft_mean, chroma_stft_std,
            rms_mean, melspectrogram_mean, melspectrogram_std, flatness_mean,
            poly_mean, mfcc_mean, mfcc_std, energy
        ])
        return features
    except Exception as e:
        print(f"❌ Error processing {file_path}: {e}")
        return None

def process_gunshot_dataset(dataset_dir, output_csv):
    """
    Gunshot audio dataset üzerinde özellik çıkarımı yapar ve CSV'e kaydeder.
    """
    features_list = []
    for weapon_type in os.listdir(dataset_dir):
        weapon_path = os.path.join(dataset_dir, weapon_type)
        if os.path.isdir(weapon_path):
            for file_name in os.listdir(weapon_path):
                if file_name.lower().endswith((".wav", ".mp3", ".flac")):
                    file_path = os.path.join(weapon_path, file_name)
                    features = extract_features(file_path)
                    if features is not None:
                        features_list.append([*features, weapon_type])
    
    columns = (
        ['zero_crossing', 'centroid_mean', 'rolloff_mean', 'bandwidth_mean'] +
        [f'contrast_mean_{i}' for i in range(7)] +
        [f'contrast_std_{i}' for i in range(7)] +
        [f'chroma_stft_mean_{i}' for i in range(12)] +
        [f'chroma_stft_std_{i}' for i in range(12)] +
        ['rms_mean', 'melspectrogram_mean', 'melspectrogram_std', 'flatness_mean'] +
        [f'poly_mean_{i}' for i in range(2)] +
        [f'mfcc_mean_{i}' for i in range(40)] +
        [f'mfcc_std_{i}' for i in range(40)] +
        ['energy', 'weapon_type']
    )
    
    df = pd.DataFrame(features_list, columns=columns)
    df.to_csv(output_csv, index=False)
    print(f"✅ Özellik çıkarımı tamamlandı ve '{output_csv}' dosyasına kaydedildi.")

if __name__ == "__main__":
    dataset_dir = "/kaggle/input/gunshot-audio-dataset"
    process_gunshot_dataset(dataset_dir, "gunshot_features.csv")
# Out:
# ✅ Özellik çıkarımı tamamlandı ve 'gunshot_features.csv' dosyasına kaydedildi.

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest, mutual_info_classif, RFE, SelectFromModel, f_classif, VarianceThreshold
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import mutual_info_score

# Information Gain (IG)
def information_gain(X, y):
    scores = []
    for i in range(X.shape[1]):
        mutual_info = mutual_info_score(y, X[:, i])
        scores.append(mutual_info)
    return np.array(scores)

# Özellikleri discretize et
def discretize_features(X):
    return np.apply_along_axis(
        lambda col: np.digitize(col, bins=np.histogram_bin_edges(col, bins='auto')), axis=0, arr=X
    )

# Veriyi yükleme
def load_and_preprocess_data(csv_path):
    df = pd.read_csv(csv_path)
    X = df.drop(columns=['weapon_type']).values
    y = df['weapon_type'].values

    label_encoder = LabelEncoder()
    y_encoded = label_encoder.fit_transform(y)

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    return X_scaled, y_encoded, df.drop(columns=['weapon_type']).columns, df['weapon_type']

# Özellik seçim algoritmaları
def feature_selection_algorithms(X, y, feature_names, top_k):
    feature_ranks = {name: 0 for name in feature_names}
    X_binned = discretize_features(X)

    # IG
    ig_scores = information_gain(X_binned, y)
    ig_indices = np.argsort(ig_scores)[-top_k:]
    for idx, fi in enumerate(ig_indices):
        feature_ranks[feature_names[fi]] += (top_k - idx)

    # RFE
    rfe_model = LogisticRegression(max_iter=500, random_state=42)
    rfe_selector = RFE(estimator=rfe_model, n_features_to_select=top_k, step=1)
    rfe_selector.fit(X, y)
    rfe_features = rfe_selector.get_support(indices=True)
    for idx, fi in enumerate(rfe_features):
        feature_ranks[feature_names[fi]] += (top_k - idx)

    # SelectKBest
    skb_selector = SelectKBest(k=top_k)
    skb_selector.fit(X, y)
    skb_features = skb_selector.get_support(indices=True)
    for idx, fi in enumerate(skb_features):
        feature_ranks[feature_names[fi]] += (top_k - idx)

    # ANOVA
    anova_selector = SelectKBest(score_func=f_classif, k=top_k)
    anova_selector.fit(X, y)
    anova_features = anova_selector.get_support(indices=True)
    for idx, fi in enumerate(anova_features):
        feature_ranks[feature_names[fi]] += (top_k - idx)

    # VarianceThreshold
    vt_selector = VarianceThreshold(threshold=0.01)
    vt_selector.fit(X)
    vt_features = set(np.where(vt_selector.get_support())[0])

    # RandomForest
    rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
    rf_model.fit(X, y)
    sfm_selector = SelectFromModel(estimator=rf_model, prefit=True, threshold="mean")
    sfm_features = sfm_selector.get_support(indices=True)
    for idx, fi in enumerate(sfm_features):
        feature_ranks[feature_names[fi]] += (top_k - idx)

    # Sıralama
    sorted_features = sorted(feature_ranks.items(), key=lambda x: x[1], reverse=True)
    top_features = sorted_features[:top_k]
    top_feature_names = [name for name, score in top_features]
    top_feature_scores = [score for name, score in top_features]

    return top_feature_names, top_feature_scores

# Seçilen özellikleri kaydet
def save_selected_features(X, top_feature_names, feature_names, target_series):
    selected_indices = [i for i, name in enumerate(feature_names) if name in top_feature_names]
    X_selected = X[:, selected_indices]
    selected_df = pd.DataFrame(X_selected, columns=top_feature_names)
    selected_df['weapon_type'] = target_series.values
    selected_df.to_csv("selected_features.csv", index=False)
    print(f"✅ Seçilen {len(top_feature_names)} özellik başarıyla kaydedildi.")

# ======================================
if __name__ == "__main__":
    csv_path = "gunshot_features.csv"
    top_k = 100   # 🔥 BURAYI istediğin kadar dinamik değiştir
    X_scaled, y_encoded, feature_names, weapon_types = load_and_preprocess_data(csv_path)

    top_feature_names, top_feature_scores = feature_selection_algorithms(
        X_scaled, y_encoded, feature_names, top_k=top_k
    )

    print(f"\nSeçilen En İyi {top_k} Özellikler:")
#    for name, score in zip(top_feature_names, top_feature_scores):
#        print(f"{name}: {score}")

    save_selected_features(X_scaled, top_feature_names, feature_names, weapon_types)
# Out:
# Seçilen En İyi 100 Özellikler:
# ✅ Seçilen 100 özellik başarıyla kaydedildi.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint

# 1. VERİYİ YÜKLEME
csv_path = "/kaggle/working/selected_features.csv"
df = pd.read_csv(csv_path)

# 2. ÖZELLİKLER ve LABEL
features = df.drop(columns=['weapon_type']).values
labels = df['weapon_type'].values

# 3. LABEL ENCODING
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)

# 4. ONE-HOT ENCODING
one_hot_encoder = OneHotEncoder(sparse_output=False)
labels_one_hot = one_hot_encoder.fit_transform(labels_encoded.reshape(-1, 1))

# 5. TRAIN-TEST SPLIT
X_train, X_test, y_train, y_test = train_test_split(features, labels_one_hot, test_size=0.2, random_state=42)

# 6. STANDARDIZATION
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model

# MODEL
input_dim = X_train.shape[1]
num_classes = y_train.shape[1]

model = Sequential([
    Dense(1000, activation='relu', input_shape=(input_dim,)),
    Dense(750, activation='relu'),
    Dense(500, activation='relu'),
    Dense(250, activation='relu'),
    Dense(100, activation='relu'),
    Dense(50, activation='relu'),
    Dense(num_classes, activation='softmax')
])

# DERLE
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.001),
    metrics=['accuracy']
)

# CALLBACK
checkpoint = ModelCheckpoint(
    "best_gunshot_cnn.keras", monitor='val_accuracy',
    save_best_only=True, mode='max', verbose=1
)

# EĞİT
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=60,
    batch_size=64,
    verbose=1,
    callbacks=[checkpoint]
)

# TEST
best_model = load_model("best_gunshot_cnn.keras")
test_loss, test_accuracy = best_model.evaluate(X_test, y_test, verbose=0)
print(f"\nPure Dense Model Test Accuracy: {test_accuracy:.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1751982925.992888      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Epoch 1/60
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751982929.799954     111 service.cc:148] XLA service 0x7be4280121c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751982929.800434     111 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1751982930.140167     111 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.1719 - loss: 2.1790
# I0000 00:00:1751982931.246589     111 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.3510 - loss: 1.8770
# Epoch 1: val_accuracy improved from -inf to 0.56725, saving model to best_gunshot_cnn.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 266ms/step - accuracy: 0.3604 - loss: 1.8550 - val_accuracy: 0.5673 - val_loss: 1.1510
# Epoch 2/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7344 - loss: 0.9219
# Epoch 2: val_accuracy improved from 0.56725 to 0.63743, saving model to best_gunshot_cnn.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6803 - loss: 0.9120 - val_accuracy: 0.6374 - val_loss: 0.9339
# Epoch 3/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7188 - loss: 0.7011
# Epoch 3: val_accuracy improved from 0.63743 to 0.68421, saving model to best_gunshot_cnn.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7482 - loss: 0.6323 - val_accuracy: 0.6842 - val_loss: 0.7153
# Epoch 4/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7969 - loss: 0.5329
# Epoch 4: val_accuracy improved from 0.68421 to 0.82456, saving model to best_gunshot_cnn.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8080 - loss: 0.4417 - val_accuracy: 0.8246 - val_loss: 0.5278
# Epoch 5/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8125 - loss: 0.3037
# Epoch 5: val_accuracy did not improve from 0.82456
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8549 - loss: 0.2725 - val_accuracy: 0.7485 - val_loss: 0.4402
# Epoch 6/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9219 - loss: 0.2087
# Epoch 6: val_accuracy did not improve from 0.82456
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8914 - loss: 0.2247 - val_accuracy: 0.7310 - val_loss: 0.4714
# Epoch 7/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8906 - loss: 0.1886
# Epoch 7: val_accuracy did not improve from 0.82456
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8874 - loss: 0.1985 - val_accuracy: 0.7427 - val_loss: 0.5353
# Epoch 8/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9375 - loss: 0.1308
# Epoch 8: val_accuracy did not improve from 0.82456
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9038 - loss: 0.1627 - val_accuracy: 0.7193 - val_loss: 0.5187
# Epoch 9/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9375 - loss: 0.1414
# Epoch 9: val_accuracy did not improve from 0.82456
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8984 - loss: 0.1716 - val_accuracy: 0.7310 - val_loss: 0.4779
# Epoch 10/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9219 - loss: 0.1631
# Epoch 10: val_accuracy improved from 0.82456 to 0.83626, saving model to best_gunshot_cnn.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9045 - loss: 0.1673 - val_accuracy: 0.8363 - val_loss: 0.4831
# Epoch 11/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8594 - loss: 0.1824
# Epoch 11: val_accuracy did not improve from 0.83626
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8755 - loss: 0.1709 - val_accuracy: 0.7310 - val_loss: 0.5599
# Epoch 12/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9375 - loss: 0.0998
# Epoch 12: val_accuracy did not improve from 0.83626
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8937 - loss: 0.1550 - val_accuracy: 0.7076 - val_loss: 0.6031
# Epoch 13/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9688 - loss: 0.0930
# Epoch 13: val_accuracy improved from 0.83626 to 0.84795, saving model to best_gunshot_cnn.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9299 - loss: 0.1408 - val_accuracy: 0.8480 - val_loss: 0.5219
# Epoch 14/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8750 - loss: 0.1960
# Epoch 14: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8838 - loss: 0.1735 - val_accuracy: 0.7251 - val_loss: 0.5407
# Epoch 15/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8750 - loss: 0.2134
# Epoch 15: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8903 - loss: 0.1671 - val_accuracy: 0.7193 - val_loss: 0.5449
# Epoch 16/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9219 - loss: 0.1492
# Epoch 16: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9066 - loss: 0.1566 - val_accuracy: 0.7778 - val_loss: 0.5801
# Epoch 17/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8750 - loss: 0.2089
# Epoch 17: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8869 - loss: 0.1707 - val_accuracy: 0.7076 - val_loss: 0.5880
# Epoch 18/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9062 - loss: 0.1630
# Epoch 18: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8910 - loss: 0.1550 - val_accuracy: 0.7251 - val_loss: 0.5654
# Epoch 19/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9062 - loss: 0.1635
# Epoch 19: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9152 - loss: 0.1499 - val_accuracy: 0.7310 - val_loss: 0.6017
# Epoch 20/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9219 - loss: 0.1190
# Epoch 20: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8825 - loss: 0.1620 - val_accuracy: 0.7251 - val_loss: 0.7555
# Epoch 21/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8750 - loss: 0.1871
# Epoch 21: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8915 - loss: 0.1636 - val_accuracy: 0.7135 - val_loss: 0.6216
# Epoch 22/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8750 - loss: 0.1419
# Epoch 22: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9036 - loss: 0.1551 - val_accuracy: 0.7135 - val_loss: 0.6602
# Epoch 23/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9062 - loss: 0.1421
# Epoch 23: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8967 - loss: 0.1487 - val_accuracy: 0.7076 - val_loss: 0.7779
# Epoch 24/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8906 - loss: 0.1527
# Epoch 24: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9109 - loss: 0.1454 - val_accuracy: 0.7778 - val_loss: 0.6467
# Epoch 25/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9219 - loss: 0.1235
# Epoch 25: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9094 - loss: 0.1431 - val_accuracy: 0.7251 - val_loss: 0.7115
# Epoch 26/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9062 - loss: 0.1423
# Epoch 26: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9034 - loss: 0.1525 - val_accuracy: 0.7193 - val_loss: 0.7979
# Epoch 27/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8906 - loss: 0.1696
# Epoch 27: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8851 - loss: 0.1556 - val_accuracy: 0.7135 - val_loss: 0.8252
# Epoch 28/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9062 - loss: 0.1385
# Epoch 28: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9025 - loss: 0.1430 - val_accuracy: 0.7193 - val_loss: 0.8208
# Epoch 29/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9219 - loss: 0.1278
# Epoch 29: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9141 - loss: 0.1338 - val_accuracy: 0.7368 - val_loss: 0.8097
# Epoch 30/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9219 - loss: 0.1469
# Epoch 30: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9133 - loss: 0.1440 - val_accuracy: 0.7135 - val_loss: 0.8975
# Epoch 31/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8750 - loss: 0.1816
# Epoch 31: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8940 - loss: 0.1551 - val_accuracy: 0.7427 - val_loss: 0.8361
# Epoch 32/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9062 - loss: 0.1147
# Epoch 32: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9085 - loss: 0.1525 - val_accuracy: 0.7076 - val_loss: 0.8935
# Epoch 33/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9062 - loss: 0.1404
# Epoch 33: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8819 - loss: 0.1661 - val_accuracy: 0.7193 - val_loss: 0.8799
# Epoch 34/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8594 - loss: 0.2743
# Epoch 34: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8837 - loss: 0.2265 - val_accuracy: 0.7076 - val_loss: 1.0938
# Epoch 35/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8594 - loss: 0.2891
# Epoch 35: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8448 - loss: 0.4004 - val_accuracy: 0.7602 - val_loss: 0.4548
# Epoch 36/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8438 - loss: 0.2714
# Epoch 36: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8350 - loss: 0.3868 - val_accuracy: 0.7135 - val_loss: 0.5948
# Epoch 37/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8438 - loss: 0.2306
# Epoch 37: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8691 - loss: 0.2645 - val_accuracy: 0.7485 - val_loss: 0.6587
# Epoch 38/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9219 - loss: 0.1972
# Epoch 38: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8495 - loss: 0.3024 - val_accuracy: 0.7778 - val_loss: 0.3732
# Epoch 39/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8906 - loss: 0.1305
# Epoch 39: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8731 - loss: 0.1918 - val_accuracy: 0.7544 - val_loss: 0.5685
# Epoch 40/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8594 - loss: 0.2227
# Epoch 40: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8675 - loss: 0.2208 - val_accuracy: 0.7251 - val_loss: 0.5874
# Epoch 41/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9062 - loss: 0.1900
# Epoch 41: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8950 - loss: 0.1726 - val_accuracy: 0.7544 - val_loss: 0.4819
# Epoch 42/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8906 - loss: 0.1755
# Epoch 42: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8983 - loss: 0.1724 - val_accuracy: 0.8246 - val_loss: 0.4799
# Epoch 43/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9375 - loss: 0.1360
# Epoch 43: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8886 - loss: 0.1709 - val_accuracy: 0.7602 - val_loss: 0.5314
# Epoch 44/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8750 - loss: 0.3114
# Epoch 44: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8954 - loss: 0.2021 - val_accuracy: 0.7836 - val_loss: 0.4360
# Epoch 45/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8594 - loss: 0.2063
# Epoch 45: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8767 - loss: 0.1814 - val_accuracy: 0.7368 - val_loss: 0.6409
# Epoch 46/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9219 - loss: 0.1413
# Epoch 46: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8988 - loss: 0.1753 - val_accuracy: 0.7368 - val_loss: 0.5786
# Epoch 47/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8750 - loss: 0.1873
# Epoch 47: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8989 - loss: 0.1599 - val_accuracy: 0.7485 - val_loss: 0.5628
# Epoch 48/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9219 - loss: 0.1254
# Epoch 48: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8967 - loss: 0.1516 - val_accuracy: 0.7485 - val_loss: 0.5657
# Epoch 49/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8906 - loss: 0.1489
# Epoch 49: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8886 - loss: 0.1485 - val_accuracy: 0.7485 - val_loss: 0.6126
# Epoch 50/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9062 - loss: 0.1298
# Epoch 50: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8950 - loss: 0.1479 - val_accuracy: 0.7310 - val_loss: 0.6412
# Epoch 51/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8594 - loss: 0.1901
# Epoch 51: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8941 - loss: 0.1515 - val_accuracy: 0.7368 - val_loss: 0.6450
# Epoch 52/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9062 - loss: 0.1720
# Epoch 52: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8988 - loss: 0.1533 - val_accuracy: 0.7368 - val_loss: 0.7324
# Epoch 53/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9219 - loss: 0.1681
# Epoch 53: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9155 - loss: 0.1393 - val_accuracy: 0.7427 - val_loss: 0.7008
# Epoch 54/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9062 - loss: 0.1213
# Epoch 54: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9049 - loss: 0.1438 - val_accuracy: 0.7427 - val_loss: 0.8148
# Epoch 55/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9219 - loss: 0.1475
# Epoch 55: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8931 - loss: 0.1609 - val_accuracy: 0.7719 - val_loss: 0.6125
# Epoch 56/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8906 - loss: 0.2029
# Epoch 56: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9000 - loss: 0.1530 - val_accuracy: 0.7485 - val_loss: 0.6880
# Epoch 57/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9531 - loss: 0.1234
# Epoch 57: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9116 - loss: 0.1419 - val_accuracy: 0.7368 - val_loss: 0.7003
# Epoch 58/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8750 - loss: 0.1466
# Epoch 58: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8926 - loss: 0.1430 - val_accuracy: 0.7368 - val_loss: 0.8205
# Epoch 59/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9531 - loss: 0.0662
# Epoch 59: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9078 - loss: 0.1327 - val_accuracy: 0.7368 - val_loss: 0.9085
# Epoch 60/60
#  1/11 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8906 - loss: 0.1424
# Epoch 60: val_accuracy did not improve from 0.84795
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9040 - loss: 0.1298 - val_accuracy: 0.7427 - val_loss: 0.9248
#
# Pure Dense Model Test Accuracy: 0.8480

# %%
# 12. EN İYİ MODELİ YÜKLE
best_model = load_model("best_gunshot_cnn.keras")

# 13. TEST ÜZERİNDE DEĞERLENDİR
test_loss, test_accuracy = best_model.evaluate(X_test, y_test, verbose=0)
print(f"\n✅ EBest Model Test Accuracy: {test_accuracy:.4f}")
